# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
from tqdm import tqdm
import sys
import matplotlib as mpl

#insert path
sys.path.insert(0, '../methods/')

sys.modules.pop('generate_syn_data', None)
from generate_syn_data import *

sys.modules.pop('ARWQE', None)
from ARWQE import *

sys.modules.pop('plots', None)
from plots import *

# %%
tasks = ['linreg', 'mean']
shifts = ['stationary', 'nonstationary']

fixed_windows = [1, 4, 16, 64, 256, 1024]
train_windows = [1, 64, 256, 1024] 
methods = methods = ['ARW'] + ['weighted'] + [f'Val_{k}' for k in fixed_windows]

alpha = 0.1
num_trials = 50

# %%
tasks = ['mean', 'linreg']
shifts = ['stationary', 'nonstationary']
rhos = [0.99, 0.9, 0.5, 0.25]
fixed_windows = [1, 4, 16, 64, 256, 1024]
train_windows = [1, 64, 256, 1024] 
methods = ['ARW'] + [rf'W{rho}' for rho in rhos] + [rf'$V{k}$' for k in fixed_windows]

alpha = 0.1
num_trials = 50

colors = ['#FFCCCC', '#FFDAB9', '#E6E6FA', '#CD853F', '#98FB98', '#B0E0E6', '#D3D3D3', '#BDB76B', '#AFEEEE', '#FFC0CB', '#FFE4B5']

for task in tasks:
    for shift in shifts:
        print(task, shift)
        cdf_array = np.load(f'./results/{task}_{shift}_cdf_array_2_rhos.npy')
        mae_array = np.abs(cdf_array - 1 + alpha)

        for m in range(0,1):
            print('train window:', train_windows[m])
            mae = np.mean(np.mean(mae_array[:, :, m, 100:], axis=2), axis=0)
            se_ae = np.std(np.mean(mae_array[:, :, m, 100:], axis=2), axis=0) / np.sqrt(num_trials) 

            plt.figure(figsize=(5,4))
            plt.bar(methods, mae, color=colors, edgecolor='black', width=1)
            plt.xticks(rotation=45)

            #uncomment to save figure
            #plt.savefig(f'./figures/{task}_{shift}.pdf', bbox_inches='tight')
# Out:
# mean stationary
# train window: 1
# mean nonstationary
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 16
#      14 for shift in shifts:
#      15     print(task, shift)
# ---> 16     cdf_array = np.load(f'./results/{task}_{shift}_cdf_array_1_rhos.npy')
#      17     mae_array = np.abs(cdf_array - 1 + alpha)
#      19     for m in range(0,1):
#
# File ~/Library/Python/3.9/lib/python/site-packages/numpy/lib/npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: './results/mean_nonstationary_cdf_array_1_rhos.npy'
