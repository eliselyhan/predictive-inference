# %%
from google.colab import drive
drive.mount('/content/drive')

import sys
sys.path.append('/content/drive/MyDrive/Colab Notebooks/NeurIPS2024')

import numpy as np
import pandas as pd
import pickle

from realdata import *

import os


# load data
path = '/content/drive/MyDrive/Colab Notebooks/NeurIPS2024'
df_raw = pd.read_csv(path + '/Transactions.csv')
encoding = 'label'
df = preprocess(df = df_raw, encoding = encoding)
# Out:
# Mounted at /content/drive

# %%
#algo = 'RF'
algo = 'XGB'


D = 10
M = int(np.ceil(826 / D))
list_t = np.array(range(1, M)) * D

prop = [0.3, 0.1]
window_sizes_train = [1, 16, 256, 1024]
window_sizes_infer = [1, 16, 256, 1024]
weights = [0.99, 0.9, 0.5, 0.25]
alpha = 0.1
delta = 0.1

test_next = False




idx_seeds = np.arange(1, 41)
le = idx_seeds[0]
results = []

for (i, s) in enumerate(idx_seeds):
    seed = s * 100
    data = splitting(df0 = df, prop = prop, seed = seed)
    results_seed = test_online(data, algo, list_t, window_sizes_train, window_sizes_infer, weights, test_next, alpha, delta, seed)
    results.append(results_seed)
    print('seed index {} finished'.format(s))

    if s % 10 == 0:
        filename = path + '/{}_{}_{}_{}.pkl'.format(algo, le, s, test_next)
        with open(filename, 'wb') as f:
            pickle.dump(results, f)
        print('intermediate results saved: ', le, s)
        results = []
        le = s + 1
# Out:
# seed index 1 finished
# seed index 2 finished
# seed index 3 finished
# seed index 4 finished
# seed index 5 finished
# seed index 6 finished
# seed index 7 finished
# seed index 8 finished
# seed index 9 finished
# seed index 10 finished
# intermediate results saved:  1 10
# seed index 11 finished
# seed index 12 finished
# seed index 13 finished
# seed index 14 finished
# seed index 15 finished
# seed index 16 finished
# seed index 17 finished
# seed index 18 finished
# seed index 19 finished
# seed index 20 finished
# intermediate results saved:  11 20
# seed index 21 finished
# seed index 22 finished
# seed index 23 finished
# seed index 24 finished
# seed index 25 finished
# seed index 26 finished
# seed index 27 finished
# seed index 28 finished
# seed index 29 finished
# seed index 30 finished
# intermediate results saved:  21 30
# seed index 31 finished
# seed index 32 finished
# seed index 33 finished
# seed index 34 finished
# seed index 35 finished
# seed index 36 finished
# seed index 37 finished
# seed index 38 finished
# seed index 39 finished
# seed index 40 finished
# intermediate results saved:  31 40

# %%
'''
with open(filename, 'rb') as r:
    lst = pickle.load(r)

idx_start = int(100/D)
MAE, AC, AW = summarize(lst[0], alpha, idx_start)

'''
