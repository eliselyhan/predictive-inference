# %%
from google.colab import drive
drive.mount('/content/drive')

import sys
path = '/content/drive/MyDrive/Colab Notebooks/NeurIPS2024'
sys.path.append(path)

import numpy as np
import pandas as pd
import pickle

from realdata import *

import os


# load data
df_raw = pd.read_csv(path + '/Transactions.csv')
encoding = 'label'
df = preprocess(df = df_raw, encoding = encoding)
# Out:
# Mounted at /content/drive

# %%
#algo = 'RF'
algo = 'XGB'


D = 10
M = int(np.ceil(826 / D))
list_t = np.array(range(1, M)) * D

prop = [0.3, 0.1]
window_sizes_train = [1, 16, 256, 1024]
window_sizes_infer = [1, 4, 16, 64, 256, 1024]
weights = [0.99, 0.9, 0.5, 0.25]
alpha = 0.1
delta = 0.1

test_next = False




idx_seeds = np.arange(41, 71)
le = idx_seeds[0]
results = []

for (i, s) in enumerate(idx_seeds):
    seed = s * 100
    data = splitting(df0 = df, prop = prop, seed = seed)
    results_seed = test_online(data, algo, list_t, window_sizes_train, window_sizes_infer, weights, test_next, alpha, delta, seed)
    results.append(results_seed)
    print('seed index {} finished'.format(s))

    if s % 10 == 0:
        filename = path + '/results/{}_{}_{}_{}.pkl'.format(algo, le, s, test_next)
        with open(filename, 'wb') as f:
            pickle.dump(results, f)
        print('intermediate results saved: ', le, s)
        results = []
        le = s + 1
# Out:
# seed index 41 finished
# seed index 42 finished
# seed index 43 finished
# seed index 44 finished
# seed index 45 finished
# seed index 46 finished
# seed index 47 finished
# seed index 48 finished
# seed index 49 finished
# seed index 50 finished
# intermediate results saved:  41 50
# seed index 51 finished
# seed index 52 finished
# seed index 53 finished
# seed index 54 finished
# seed index 55 finished
# seed index 56 finished
# seed index 57 finished
# seed index 58 finished
# seed index 59 finished
# seed index 60 finished
# intermediate results saved:  51 60
# seed index 61 finished
# seed index 62 finished
# seed index 63 finished
# seed index 64 finished
# seed index 65 finished
# seed index 66 finished
# seed index 67 finished
# seed index 68 finished
# seed index 69 finished
# seed index 70 finished
# intermediate results saved:  61 70
